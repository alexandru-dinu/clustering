# %%
from sklearn.datasets import make_blobs
import seaborn as sns

# %%
seed = 0
X, y = make_blobs(n_samples=1000, centers=3, n_features=2, random_state=seed)

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette='flare')
# Out:
# <AxesSubplot: >
